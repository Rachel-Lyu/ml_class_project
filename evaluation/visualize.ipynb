# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from scipy import stats
from functools import reduce
# import umap

# %%
def add_kmer_cnt(seq, K):
    tmp = dict.fromkeys(reduce(lambda x,y: [i+j for i in x for j in y], [['A','T','C','G']] * K), 0)
    for i in range(len(seq) - K + 1):
        tmp[seq[i:i+K]] += 1
    return tmp

def get_sorted_kmer_dict_hl_(inputFile, K):
    d = dict.fromkeys(reduce(lambda x,y: [i+j for i in x for j in y], [['A','T','C','G']] * K), np.array([]))
    # ctrl_cnt = 0
    with open(inputFile, 'r') as inp:
        for line in inp:
            line = inp.readline()
            tmp = add_kmer_cnt(line.strip(), K)
            for k in tmp.keys():
                d[k] = np.append(d[k], tmp[k])
            # ctrl_cnt = ctrl_cnt + 1
            # if ctrl_cnt == 1000:
            #     break
    # d = sorted(d.items(), key = lambda kv:(kv[1], kv[0]), reverse = True)

    return dict(d)
    
def getGC(inputFile):
    Aarr = np.array([])
    Tarr = np.array([])
    Garr = np.array([])
    Carr = np.array([])
    with open(inputFile, 'r') as inp:
        for line in inp:
            seq = line.strip()
            Aarr = np.append(Aarr, seq.count('A'))
            Tarr = np.append(Tarr, seq.count('T'))
            Garr = np.append(Garr, seq.count('G'))
            Carr = np.append(Carr, seq.count('C'))
    return np.array([Aarr,Tarr,Garr,Carr]) 
    
def getGC_dbl_lines(inputFile):
    Aarr = np.array([])
    Tarr = np.array([])
    Garr = np.array([])
    Carr = np.array([])
    with open(inputFile, 'r') as inp:
        for line in inp:
            seq = inp.readline().strip()
            Aarr = np.append(Aarr, seq.count('A'))
            Tarr = np.append(Tarr, seq.count('T'))
            Garr = np.append(Garr, seq.count('G'))
            Carr = np.append(Carr, seq.count('C'))
    return np.array([Aarr,Tarr,Garr,Carr]) 

def kmer_cnt(seq, K, d):
    for i in range(len(seq) - K + 1):
        d[seq[i:i+K]] += 1
    return d

def get_sorted_kmer_dict(inputFile, K):
    d = dict.fromkeys(reduce(lambda x,y: [i+j for i in x for j in y], [['A','T','C','G']] * K), 0)
    with open(inputFile, 'r') as inp:
        for line in inp:
            line = inp.readline().strip()
            d = kmer_cnt(line, K, d)
    d = sorted(d.items(), key = lambda kv:(kv[1], kv[0]), reverse = True)
    return d

# %%
fnm_Pos = ['/home/mleone2/ml_class_project/results/fold' + str(i) + '_testPos_1000result.txt' for i in range(1, 6)]
fnm_Neg10x = ['/home/mleone2/ml_class_project/results/fold' + str(i) + '_testNeg10x_1000result.txt' for i in range(1, 6)]
fnm_random = ['/home/mleone2/ml_class_project/results/random_seqs_test' + str(i) + '_predictions_10000result.txt' for i in range(1, 6)]

# %%
arr_Pos = np.array([])
arr_Neg10x = np.array([])
arr_random = np.array([])
for fnm in fnm_Pos:
    with open(fnm, 'r') as inp:
        for line in inp:
            arr_Pos = np.append(arr_Pos, float(line.strip()))
for fnm in fnm_Neg10x:
    with open(fnm, 'r') as inp:
        for line in inp:
            arr_Neg10x = np.append(arr_Neg10x, float(line.strip()))
for fnm in fnm_random:
    with open(fnm, 'r') as inp:
        for line in inp:
            arr_random = np.append(arr_random, float(line.strip()))

# %%
plt.hist(arr_Pos, bins=100, weights=np.zeros_like(arr_Pos) + 100 / len(arr_Pos), label = 'Positive samples', alpha = 0.6, color = 'tab:cyan');
plt.hist(arr_Neg10x, bins=100, weights=np.zeros_like(arr_Neg10x) + 100 / len(arr_Neg10x), label = 'Negative samples', alpha = 0.6, color = 'tab:pink');
plt.hist(arr_random, bins=100, weights=np.zeros_like(arr_random) + 100 / len(arr_random), label = 'Random sequences', alpha = 0.5, color = 'tab:green');
plt.legend()
plt.ylabel('frequency(%)')
# Out:
# Text(0, 0.5, 'frequency(%)')

# %%
len(np.where(arr_random>0.98)[0])
# Out:
# 477

# %%
len(np.where(arr_random<0.00001)[0])
# Out:
# 672

# %%
# head -2000 /home/mleone2/ml_class_project/FASTA_CV/Mo2015_EXCpos_Ctx_fold1_testPos.fa  | awk 'NR%2==0' > Pos_score.txt

high_seq = '/home/mleone2/ml_class_project/results/high_score.txt'
low_seq = '/home/mleone2/ml_class_project/results/low_score.txt'

# %%
# def getGC_dbl_lines(inputFile):
#     Aarr = np.array([])
#     Tarr = np.array([])
#     Garr = np.array([])
#     Carr = np.array([])
#     with open(inputFile, 'r') as inp:
#         for line in inp:
#             seq = inp.readline().strip()
#             Aarr = np.append(Aarr, seq.count('A'))
#             Tarr = np.append(Tarr, seq.count('T'))
#             Garr = np.append(Garr, seq.count('G'))
#             Carr = np.append(Carr, seq.count('C'))
#     return np.array([Aarr,Tarr,Garr,Carr]) 

ATGC_pos = getGC_dbl_lines('/home/mleone2/ml_class_project/FASTA_CV/Mo2015_EXCpos_Ctx_fold1_validPos.fa')
ATGC_pos = ATGC_pos/np.sum(ATGC_pos, axis =0)
ATGC_neg = getGC_dbl_lines('/home/mleone2/ml_class_project/FASTA_CV/Mo2015_EXCpos_Ctx_fold1_validNeg10x.fa')
ATGC_neg = ATGC_neg/np.sum(ATGC_neg, axis =0)
GCpos = ATGC_pos[2]+ATGC_pos[3]
GCneg = ATGC_neg[2]+ATGC_neg[3]

# %%
plt.hist(GCpos, weights=np.ones_like(GCpos) / len(GCpos), alpha = 0.5, label='Positive seq', bins=np.linspace(0.2, 0.7, num = 60))
plt.hist(GCneg, weights=np.ones_like(GCneg) / len(GCneg), alpha = 0.5, label='Negative seq', bins=np.linspace(0.2, 0.7, num = 60))
plt.legend();
plt.ylabel('frequency(%)')
# Out:
# Text(0, 0.5, 'frequency(%)')

# %%
stats.ttest_ind(GCpos, GCneg, equal_var = True, alternative = 'greater')

# %%
# ATGC_pos = getGC(pos_seq)
# ATGC_pos = ATGC_pos/np.sum(ATGC_pos, axis =0)
# ATGC_neg = getGC(neg_seq)
# ATGC_neg = ATGC_neg/np.sum(ATGC_neg, axis =0)
# GCpos = ATGC_pos[2]+ATGC_pos[3]
# GCneg = ATGC_neg[2]+ATGC_neg[3]
# plt.hist(GCpos, weights=np.zeros_like(GCpos) + 100 / len(GCpos), alpha = 0.5, label='Positive seq', bins=30)
# plt.hist(GCneg, weights=np.zeros_like(GCneg) + 100 / len(GCneg), alpha = 0.5, label='Negative seq', bins=30)
# plt.legend();
# plt.ylabel('frequency(%)')

# %%
K = 5
# def add_kmer_cnt(seq, K):
#     tmp = dict.fromkeys(reduce(lambda x,y: [i+j for i in x for j in y], [['A','T','C','G']] * K), 0)
#     for i in range(len(seq) - K + 1):
#         tmp[seq[i:i+K]] += 1
#     return tmp

def get_sorted_kmer_dict_hl_(inputFile, K):
    d = dict.fromkeys(reduce(lambda x,y: [i+j for i in x for j in y], [['A','T','C','G']] * K), np.array([]))
    # ctrl_cnt = 0
    with open(inputFile, 'r') as inp:
        for line in inp:
            line = inp.readline()
            tmp = add_kmer_cnt(line.strip(), K)
            for k in tmp.keys():
                d[k] = np.append(d[k], tmp[k])
            # ctrl_cnt = ctrl_cnt + 1
            # if ctrl_cnt == 1000:
                # break
    # d = sorted(d.items(), key = lambda kv:(kv[1], kv[0]), reverse = True)

    return dict(d)
# cat /home/mleone2/ml_class_project/FASTA_CV/Mo2015_EXCpos_Ctx_fold1_validPos.fa | awk 'NR%2==0' | shuf -n 1000 -o /home/mleone2/ml_class_project/results/Mo2015_EXCpos_Ctx_fold1_validPos_shuf1000.fa
# cat /home/mleone2/ml_class_project/FASTA_CV/Mo2015_EXCpos_Ctx_fold1_validNeg10x.fa | awk 'NR%2==0' | shuf -n 1000 -o /home/mleone2/ml_class_project/results/Mo2015_EXCpos_Ctx_fold1_validNeg10x_shuf1000.fa
pos_seq = '/home/mleone2/ml_class_project/results/Mo2015_EXCpos_Ctx_fold1_validPos_shuf1000.fa'
neg_seq = '/home/mleone2/ml_class_project/results/Mo2015_EXCpos_Ctx_fold1_validNeg10x_shuf1000.fa'
dp = get_sorted_kmer_dict_hl_(pos_seq, K)
dn = get_sorted_kmer_dict_hl_(neg_seq, K)

dfp = pd.DataFrame.from_dict(dp)
dfp.insert(0, 'class', 'Positive')
# dfh.head()

dfn = pd.DataFrame.from_dict(dn)
dfn.insert(0, 'class', 'Negative')
# dfh.head()
df = pd.concat([dfp, dfn])
df = df.reset_index(drop=True)
# df

pca = PCA(n_components=2)
x = df.drop(['class'], axis=1)
y = df.iloc[[0]]
principalComponents = pca.fit_transform(x)
x = StandardScaler().fit_transform(x)
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2'])
principalDf
finalDf = pd.concat([principalDf, df[['class']]], axis = 1)

fig = plt.figure()
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1')
ax.set_ylabel('Principal Component 2')
# ax.set_title('2 component PCA', fontsize = 20)
targets = ['Positive', 'Negative']
colors = ['tab:pink', 'tab:cyan']
for target, color in zip(targets,colors):
    indicesToKeep = finalDf['class'] == target
    ax.scatter(finalDf.loc[indicesToKeep, 'principal component 1']
               , finalDf.loc[indicesToKeep, 'principal component 2']
               , c = color
               , s = 15, alpha=0.7)
ax.legend(targets)
ax.grid()

# %%
orig_seqs = get_sorted_kmer_dict_hl("/home/mleone2/ml_class_project/results/satmut_orig_seqs_as_strings.txt", K)
mut_seqs =  get_sorted_kmer_dict_hl("/home/mleone2/ml_class_project/results/satmut_seqs_as_strings.txt", K)
len(orig_seqs['AAAAA'])
# Out:
# 200

# %%
dfo = pd.DataFrame.from_dict(orig_seqs)
dfo.insert(0, 'class', 'Before mutation')
# dfh.head()

dfm = pd.DataFrame.from_dict(mut_seqs)
dfm.insert(0, 'class', 'After mutation')
# dfh.head()

dfnew = pd.concat([dfp, dfn, dfo, dfm])
dfnew = dfnew.reset_index(drop=True)

# df
newx = dfnew.drop(['class'], axis=1)
newy = dfnew.iloc[[0]]

principalComponents_new = pca.transform(newx)
principalDf_new = pd.DataFrame(data = principalComponents_new
             , columns = ['principal component 1', 'principal component 2'])
principalDf_new
finalDf_new = pd.concat([principalDf_new, dfnew[['class']]], axis = 1)

# %%
finalDf_new
# Out:
#       principal component 1  principal component 2           class
# 0                  3.802673              -6.222871        Positive
# 1                  6.667808              -3.015337        Positive
# 2                  4.142391              -0.360845        Positive
# 3                 10.316489              -1.084284        Positive
# 4                  7.505183              -1.789912        Positive
# ...                     ...                    ...             ...
# 2395               3.627599              -0.100800  After mutation
# 2396               4.623511              -2.563868  After mutation
# 2397               0.876350              -0.357105  After mutation
# 2398               6.110301               3.464852  After mutation
# 2399               4.266234               0.695857  After mutation
#
# [2400 rows x 3 columns]

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1')
ax.set_ylabel('Principal Component 2')
# ax.set_title('2 component PCA', fontsize = 20)
targets = ['Positive', 'Negative', 'Before mutation', 'After mutation']
colors = ['tab:pink', 'tab:cyan', 'tab:green', 'tab:olive']
for target, color in zip(targets,colors):
    indicesToKeep = finalDf_new['class'] == target
    ax.scatter(finalDf_new.loc[indicesToKeep, 'principal component 1']
               , finalDf_new.loc[indicesToKeep, 'principal component 2']
               , c = color
               , s = 15, alpha=0.5)
ax.legend(targets)
ax.grid()

# %%
def getGC(inputFile):
    Aarr = np.array([])
    Tarr = np.array([])
    Garr = np.array([])
    Carr = np.array([])
    with open(inputFile, 'r') as inp:
        for line in inp:
            seq = line.strip()
            Aarr = np.append(Aarr, seq.count('A'))
            Tarr = np.append(Tarr, seq.count('T'))
            Garr = np.append(Garr, seq.count('G'))
            Carr = np.append(Carr, seq.count('C'))
    return np.array([Aarr,Tarr,Garr,Carr]) 
ATGC_high = getGC(high_seq)
ATGC_high = ATGC_high/np.sum(ATGC_high, axis =0)
ATGC_low = getGC(low_seq)
ATGC_low = ATGC_low/np.sum(ATGC_low, axis =0)
GChigh = ATGC_high[2]+ATGC_high[3]
GClow = ATGC_low[2]+ATGC_low[3]
plt.hist(GChigh, weights=np.zeros_like(GChigh) + 100 / len(GChigh), alpha = 0.5, label='high score seq', bins=np.linspace(0.3, 0.55, num = 60))
plt.hist(GClow, weights=np.zeros_like(GClow) + 100 / len(GClow), alpha = 0.5, label='low score seq', bins=np.linspace(0.3, 0.55, num = 60))
plt.legend();
plt.ylabel('frequency(%)')

# %%
stats.ttest_ind(GChigh, GClow, equal_var = True, alternative = 'greater')
# Out:
# Ttest_indResult(statistic=8.213091458054109, pvalue=2.880118222934251e-16)

# %%
stats.ttest_1samp(GChigh, popmean = 0.4268)
# Out:
# Ttest_1sampResult(statistic=2.623163830755086, pvalue=0.00899125263583053)

# %%
stats.ttest_1samp(GClow, popmean = 0.4268)
# Out:
# Ttest_1sampResult(statistic=-9.623556762816742, pvalue=1.2688208606854187e-20)

# %%
print(np.mean(GChigh))
print(np.std(GChigh))
print(np.mean(GClow))
print(np.std(GClow))
# Out:
# 0.42943881628775993
# 0.021947609119250828
# 0.4186062399011501
# 0.022055092934543562

# %%
(0.42943881628775993 - 0.4186062399011501) / np.sqrt(((0.021947609119250828 ** 2)/477) + ((0.022055092934543562 ** 2)/672))
# Out:
# 8.2270670547256

# %%
K = 5
# def add_kmer_cnt(seq, K):
#     tmp = dict.fromkeys(reduce(lambda x,y: [i+j for i in x for j in y], [['A','T','C','G']] * K), 0)
#     for i in range(len(seq) - K + 1):
#         tmp[seq[i:i+K]] += 1
#     return tmp

def get_sorted_kmer_dict_hl(inputFile, K):
    d = dict.fromkeys(reduce(lambda x,y: [i+j for i in x for j in y], [['A','T','C','G']] * K), np.array([]))
    with open(inputFile, 'r') as inp:
        for line in inp:
            tmp = add_kmer_cnt(line.strip(), K)
            for k in tmp.keys():
                d[k] = np.append(d[k], tmp[k])
    # d = sorted(d.items(), key = lambda kv:(kv[1], kv[0]), reverse = True)

    return dict(d)

dh = get_sorted_kmer_dict_hl(high_seq, K)
dl = get_sorted_kmer_dict_hl(low_seq, K)

# %%
dfh = pd.DataFrame.from_dict(dh)
dfh.insert(0, 'class', 'highScore')
# dfh.head()

# %%
dfl = pd.DataFrame.from_dict(dl)
dfl.insert(0, 'class', 'lowScore')
# dfl.head()

# %%
df = pd.concat([dfh, dfl])
df = df.reset_index(drop=True)
# df

# %%
pca = PCA(n_components=2)
x = df.drop(['class'], axis=1)
y = df.iloc[[0]]
principalComponents = pca.fit_transform(x)
x = StandardScaler().fit_transform(x)
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2'])
principalDf
finalDf = pd.concat([principalDf, df[['class']]], axis = 1)

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1')
ax.set_ylabel('Principal Component 2')
# ax.set_title('2 component PCA', fontsize = 20)
targets = ['highScore', 'lowScore']
colors = ['tab:pink', 'tab:cyan']
for target, color in zip(targets,colors):
    indicesToKeep = finalDf['class'] == target
    ax.scatter(finalDf.loc[indicesToKeep, 'principal component 1']
               , finalDf.loc[indicesToKeep, 'principal component 2']
               , c = color
               , s = 15, alpha=0.7)
ax.legend(targets)
ax.grid()

# %%
dfnew_ = pd.concat([dfh, dfl, dfo, dfm])
dfnew_ = dfnew_.reset_index(drop=True)

# df
newx_ = dfnew_.drop(['class'], axis=1)
newy_ = dfnew_.iloc[[0]]

principalComponents_new_ = pca.transform(newx_)
principalDf_new_ = pd.DataFrame(data = principalComponents_new_
             , columns = ['principal component 1', 'principal component 2'])
principalDf_new_
finalDf_new_ = pd.concat([principalDf_new_, dfnew_[['class']]], axis = 1)

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1')
ax.set_ylabel('Principal Component 2')
# ax.set_title('2 component PCA', fontsize = 20)
targets = ['highScore', 'lowScore', 'Before mutation', 'After mutation']
colors = ['tab:pink', 'tab:cyan', 'tab:brown', 'tab:olive']
for target, color in zip(targets,colors):
    indicesToKeep = finalDf_new_['class'] == target
    ax.scatter(finalDf_new_.loc[indicesToKeep, 'principal component 1']
               , finalDf_new_.loc[indicesToKeep, 'principal component 2']
               , c = color
               , s = 15, alpha=0.5)
ax.legend(targets)
ax.grid()

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1')
ax.set_ylabel('Principal Component 2')
# ax.set_title('2 component PCA', fontsize = 20)
targets = ['Before mutation', 'After mutation']
colors = ['tab:brown', 'tab:olive']
for target, color in zip(targets,colors):
    indicesToKeep = finalDf_new_['class'] == target
    ax.scatter(finalDf_new_.loc[indicesToKeep, 'principal component 1']
               , finalDf_new_.loc[indicesToKeep, 'principal component 2']
               , c = color
               , s = 15, alpha=0.5)
ax.legend(targets)
ax.grid()

# %%
reducer = umap.UMAP()
embedding = reducer.fit_transform(x)
embedding.shape
# Out:
# (1149, 2)

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('UMAP 1', fontsize = 15)
ax.set_ylabel('UMAP 2', fontsize = 15)
ax.set_title('2 component Umap', fontsize = 20)
targets = ['highScore', 'lowScore']
colors = ['r', 'g', 'b']
for target, color in zip(targets,colors):
    indicesToKeep = finalDf['class'] == target
    ax.scatter(embedding[indicesToKeep, 0]
               ,embedding[indicesToKeep, 1]
               , c = color
               , s = 50)
ax.legend(targets)
ax.grid()

# %%
K = 5
def kmer_cnt(seq, K, d):
    for i in range(len(seq) - K + 1):
        d[seq[i:i+K]] += 1
    return d

# def get_sorted_kmer_dict(inputFile, K):
#     d = dict.fromkeys(reduce(lambda x,y: [i+j for i in x for j in y], [['A','T','C','G']] * K), 0)
#     with open(inputFile, 'r') as inp:
#         for line in inp:
#             d = kmer_cnt(line.strip(), K, d)
#     d = sorted(d.items(), key = lambda kv:(kv[1], kv[0]), reverse = True)
#     return d

print(get_sorted_kmer_dict(high_seq, K)[:10])
print(get_sorted_kmer_dict(high_seq, K)[-10:])
print(get_sorted_kmer_dict(low_seq, K)[:10])
print(get_sorted_kmer_dict(low_seq, K)[-10:])
# Out:
# [('TTTTT', 545), ('AAAAT', 520), ('AAATA', 515), ('AAAAA', 512), ('ATTTT', 510), ('TAAAT', 507), ('AATTT', 500), ('TTATA', 499), ('TATTT', 499), ('TAAAA', 496)]
# [('CGACC', 98), ('CCCCC', 97), ('GACCC', 96), ('GGGGC', 92), ('GGCCC', 91), ('GGGCC', 90), ('GGCCG', 90), ('GCCCC', 87), ('CCCGG', 87), ('CGGCC', 77)]
# [('TAATA', 927), ('TTAAT', 919), ('ATTAA', 901), ('TATTA', 883), ('TTATT', 855), ('AATAA', 845), ('AATTA', 809), ('ATAAT', 793), ('TAATT', 792), ('ATTAT', 778)]
# [('CCCGC', 124), ('GGGCG', 120), ('CGCCC', 120), ('CGGGC', 116), ('CGCGC', 115), ('CGGCG', 114), ('GCGGC', 107), ('GGCGC', 106), ('CCGCG', 103), ('CGCGG', 93)]

# %%
sum(get_sorted_kmer_dict(high_seq, K).values())/477
# Out:
# 497.0

# %%
sum(get_sorted_kmer_dict(low_seq, K).values())/672

# %%
K = 5
def kmer_cnt(seq, K, d):
    for i in range(len(seq) - K + 1):
        d[seq[i:i+K]] += 1
    return d

def get_sorted_kmer_dict(inputFile, K):
    d = dict.fromkeys(reduce(lambda x,y: [i+j for i in x for j in y], [['A','T','C','G']] * K), 0)
    with open(inputFile, 'r') as inp:
        for line in inp:
            line = inp.readline().strip()
            d = kmer_cnt(line, K, d)
    d = sorted(d.items(), key = lambda kv:(kv[1], kv[0]), reverse = True)
    return d
get_sorted_kmer_dict('/home/mleone2/ml_class_project/FASTA_CV/Mo2015_EXCpos_Ctx_fold1_testPos.fa', 5)[:10]
# Out:
# [('TTTTT', 27699),
#  ('AAAAA', 27469),
#  ('TTTCT', 20380),
#  ('AGAAA', 20219),
#  ('ATTTT', 19020),
#  ('AAAAT', 18823),
#  ('TGTGT', 18141),
#  ('AGAGA', 17913),
#  ('ACACA', 17871),
#  ('TCTCT', 17824)]

# %%
get_sorted_kmer_dict('/home/mleone2/ml_class_project/FASTA_CV/Mo2015_EXCpos_Ctx_fold1_validPos.fa', 5)
# Out:
# [('AAAAA', 17786),
#  ('TTTTT', 17474),
#  ('TTTCT', 12900),
#  ('AGAAA', 12799),
#  ('ACACA', 12205),
#  ('AAAAT', 12169),
#  ('TGTGT', 12136),
#  ('ATTTT', 12066),
#  ('TCTCT', 11388),
#  ('AGAGA', 10881),
#  ('TTCTT', 10376),
#  ('TAAAA', 10309),
#  ('AAGAA', 10308),
#  ('CACAC', 10291),
#  ('TTTTA', 10256),
#  ('GAAAA', 10094),
#  ('GTGTG', 10078),
#  ('TATTT', 9984),
#  ('AAATA', 9959),
#  ('TTTTC', 9920),
#  ('TCTTT', 9894),
#  ('AAAGA', 9805),
#  ('TGTTT', 9671),
#  ('AAACA', 9449),
#  ('CATTT', 9308),
#  ('TTAAA', 9214),
#  ('AAATG', 9184),
#  ('TTTAA', 9121),
#  ('TTCCT', 9119),
#  ('CAGAA', 8950),
#  ('TTCTG', 8914),
#  ('AGGAA', 8908),
#  ('CTCTC', 8739),
#  ('CTTTT', 8730),
#  ('AAAAG', 8706),
#  ('TTTAT', 8698),
#  ('CAGAG', 8559),
#  ('TCTGT', 8491),
#  ('CTCTG', 8435),
#  ('ACAGA', 8425),
#  ('TGAAA', 8413),
#  ('ATAAA', 8334),
#  ('CTTCT', 8292),
#  ('TTTCA', 8267),
#  ('CTGTG', 8188),
#  ('TTTGT', 8184),
#  ('GGAAA', 8173),
#  ('GAGAG', 8168),
#  ('AATTT', 8156),
#  ('AAATT', 8120),
#  ('ACAAA', 8072),
#  ('AGAAG', 8048),
#  ('TTTCC', 8041),
#  ('CACAG', 8030),
#  ('TTTTG', 8002),
#  ('TTCTC', 7863),
#  ('CAAAA', 7854),
#  ('GAGAA', 7780),
#  ('GAAAG', 7661),
#  ('TCCTT', 7572),
#  ('TTATT', 7570),
#  ('CTTTC', 7525),
#  ('ATTTA', 7473),
#  ('AGCAG', 7433),
#  ('CTGCT', 7428),
#  ('AAAAC', 7391),
#  ('GTTTT', 7385),
#  ('AATAA', 7384),
#  ('TAAAT', 7370),
#  ('TGCTT', 7307),
#  ('AAGCA', 7305),
#  ('TGCTG', 7269),
#  ('TTGTT', 7230),
#  ('CAGCA', 7228),
#  ('TTCCA', 7220),
#  ('ATTTC', 7200),
#  ('GAAAT', 7179),
#  ('TCTTC', 7139),
#  ('AAGGA', 7118),
#  ('AACAA', 7117),
#  ('TGTCT', 7115),
#  ('CTCCT', 7109),
#  ('TGGAA', 7106),
#  ('CTCAG', 7080),
#  ('CTGAG', 7052),
#  ('CTTCC', 7033),
#  ('AGACA', 7002),
#  ('CTCTT', 6997),
#  ('TTCAT', 6970),
#  ('GAAGA', 6968),
#  ('AAGAG', 6933),
#  ('TCTGA', 6909),
#  ('AGGAG', 6876),
#  ('CAGCT', 6856),
#  ('GGAAG', 6790),
#  ('CTGAA', 6788),
#  ('AGAAT', 6762),
#  ('ATGAA', 6759),
#  ('AGCTG', 6752),
#  ('ATTCT', 6695),
#  ('TCATT', 6690),
#  ('TCAGA', 6669),
#  ('CAGGA', 6662),
#  ('TTCAG', 6653),
#  ('TCTCA', 6638),
#  ('TCCTG', 6637),
#  ('AATGT', 6623),
#  ('CAAAG', 6608),
#  ('TGTGA', 6576),
#  ('CTTTG', 6569),
#  ('CATCT', 6559),
#  ('CTGTT', 6525),
#  ('TTTGA', 6521),
#  ('TGAGA', 6521),
#  ('AGATG', 6520),
#  ('GCAGA', 6510),
#  ('TCACA', 6509),
#  ('CCTCT', 6481),
#  ('AATGA', 6478),
#  ('ATATT', 6436),
#  ('TCCCT', 6435),
#  ('CCTTT', 6425),
#  ('AACAG', 6393),
#  ('TTGCT', 6387),
#  ('GGAGA', 6379),
#  ('ATGTG', 6352),
#  ('AAAGC', 6348),
#  ('TCTCC', 6344),
#  ('AGAGG', 6334),
#  ('AATAT', 6330),
#  ('TCAAA', 6328),
#  ('ACATT', 6326),
#  ('AAAGG', 6321),
#  ('AGCAA', 6319),
#  ('TCCTC', 6293),
#  ('GCTTT', 6255),
#  ('AGGGA', 6243),
#  ('AGCCA', 6243),
#  ('TCTGG', 6228),
#  ('AAACT', 6223),
#  ('AGTTT', 6220),
#  ('TGTGG', 6217),
#  ('CACAT', 6217),
#  ('GAGGA', 6216),
#  ('TGCCT', 6201),
#  ('CCAGA', 6192),
#  ('ATTTG', 6192),
#  ('CCTCC', 6175),
#  ('TCTGC', 6173),
#  ('CTTCA', 6165),
#  ('CACTG', 6163),
#  ('TCCAG', 6148),
#  ('CTGCA', 6137),
#  ('TGAAG', 6136),
#  ('TATAT', 6136),
#  ('AGGCA', 6114),
#  ('TGGAG', 6103),
#  ('TGGCT', 6097),
#  ('CAGTG', 6078),
#  ('ATATA', 6078),
#  ('TGGGA', 6077),
#  ('TGCAG', 6065),
#  ('TTCTA', 6060),
#  ('CTCCA', 6060),
#  ('CAAAT', 6042),
#  ('GGGAA', 6040),
#  ('CCACA', 6021),
#  ('GGAGG', 6003),
#  ('CTGGG', 5975),
#  ('CTGGA', 5958),
#  ('ATTCA', 5955),
#  ('AATTA', 5950),
#  ('TAGAA', 5949),
#  ('TTGAA', 5933),
#  ('TAATT', 5930),
#  ('TTCAA', 5916),
#  ('AAAGT', 5905),
#  ('TTCCC', 5898),
#  ('ATCTG', 5882),
#  ('GGGAG', 5871),
#  ('ACTTT', 5862),
#  ('AACAT', 5848),
#  ('TCCCA', 5794),
#  ('ATGTT', 5792),
#  ('TGAAT', 5763),
#  ('CTGCC', 5751),
#  ('CAGAT', 5739),
#  ('AGCTT', 5734),
#  ('CCCAG', 5733),
#  ('CCTTC', 5703),
#  ('TTTGG', 5696),
#  ('GAACA', 5696),
#  ('CTCCC', 5689),
#  ('GGCAG', 5676),
#  ('TGCCA', 5639),
#  ('ACTGT', 5629),
#  ('ATCTT', 5624),
#  ('AAGCT', 5623),
#  ('AGCAT', 5618),
#  ('CTTTA', 5615),
#  ('ATGCA', 5602),
#  ('TGTTC', 5583),
#  ('CCAAA', 5570),
#  ('TGGCA', 5550),
#  ('ATGCT', 5544),
#  ('GCTCT', 5532),
#  ('TGCAT', 5530),
#  ('AAGAT', 5513),
#  ('AAATC', 5507),
#  ('AGAGC', 5504),
#  ('GATTT', 5489),
#  ('CCTGG', 5470),
#  ('GCAAA', 5466),
#  ('AGCCT', 5466),
#  ('GCTGT', 5455),
#  ('ACAGT', 5448),
#  ('GAAGG', 5423),
#  ('TGAGT', 5422),
#  ('CAAGA', 5411),
#  ('TAAAG', 5401),
#  ('ACAGC', 5394),
#  ('AACTG', 5391),
#  ('TTGTG', 5383),
#  ('AGAAC', 5367),
#  ('AGGCT', 5351),
#  ('ACACT', 5347),
#  ('TCTTG', 5344),
#  ('CAGCC', 5340),
#  ('GGCTG', 5339),
#  ('ACTGA', 5339),
#  ('CCAGG', 5338),
#  ('TTTGC', 5336),
#  ('GTTCT', 5328),
#  ('TCACT', 5321),
#  ('CTGTC', 5319),
#  ('GTTTC', 5306),
#  ('ACTCA', 5299),
#  ('CCAGC', 5296),
#  ('TGACA', 5292),
#  ('CACAA', 5292),
#  ('TTAAT', 5281),
#  ('GTGTT', 5280),
#  ('TCAGT', 5277),
#  ('CAGTT', 5268),
#  ('AGTGT', 5267),
#  ('GACAG', 5239),
#  ('TATGT', 5238),
#  ('GAAAC', 5226),
#  ('TTATA', 5218),
#  ('TTTAG', 5216),
#  ('CTAAA', 5211),
#  ('ACATA', 5209),
#  ('AATCT', 5206),
#  ('GAATT', 5180),
#  ('ATTAA', 5176),
#  ('CACTT', 5173),
#  ('AGTGA', 5172),
#  ('AGTCA', 5172),
#  ('ACATG', 5169),
#  ('TGTCA', 5163),
#  ('TGACT', 5161),
#  ('ATAAT', 5150),
#  ('GTGGG', 5141),
#  ('TATAA', 5128),
#  ('ATGGA', 5121),
#  ('GAGCA', 5113),
#  ('AGAGT', 5113),
#  ('TGTAA', 5112),
#  ('GCACA', 5110),
#  ('ATTAT', 5110),
#  ('CCCTG', 5106),
#  ('TGTAT', 5104),
#  ('TCTTA', 5102),
#  ('CATGT', 5100),
#  ('AAGTG', 5097),
#  ('TTACA', 5095),
#  ('CCTGT', 5093),
#  ('GCTGC', 5076),
#  ('TGTGC', 5063),
#  ('AATTC', 5057),
#  ('TCCAT', 5055),
#  ('TGTTG', 5053),
#  ('ATGAG', 5043),
#  ('AGCTC', 5042),
#  ('ACAGG', 5031),
#  ('GCTGG', 5025),
#  ('AGATT', 5023),
#  ('GCTGA', 5022),
#  ('ATGTA', 5019),
#  ('GCCAG', 5006),
#  ('AACAC', 4996),
#  ('TGATT', 4991),
#  ('TCAGC', 4988),
#  ('GCTTC', 4975),
#  ('TGGTG', 4964),
#  ('GTTTG', 4962),
#  ('CCCAC', 4952),
#  ('CTGGC', 4951),
#  ('CTCAT', 4951),
#  ('CAGGG', 4950),
#  ('CAAAC', 4947),
#  ('ATACA', 4944),
#  ('CCTGC', 4942),
#  ('ATATG', 4931),
#  ('TAAGA', 4921),
#  ('ACTCT', 4916),
#  ('CTTGG', 4913),
#  ('GAGCT', 4911),
#  ('TGCAA', 4910),
#  ('CACCA', 4910),
#  ('TTGGA', 4909),
#  ('AACTT', 4909),
#  ('TGCTC', 4907),
#  ('AAGTT', 4896),
#  ('GCAGC', 4891),
#  ('GCCTG', 4890),
#  ('CCAAG', 4879),
#  ('AGTCT', 4877),
#  ('AGACT', 4850),
#  ('TCCAA', 4849),
#  ('CATAT', 4841),
#  ('GAAGC', 4835),
#  ('TGAGG', 4834),
#  ('AATCA', 4833),
#  ('CATTC', 4831),
#  ('TACAT', 4829),
#  ('GAATG', 4793),
#  ('CCTCA', 4765),
#  ('TTGCA', 4764),
#  ('CAACA', 4764),
#  ('ACAAG', 4752),
#  ('CCCTC', 4744),
#  ('TGGTT', 4741),
#  ('AACCA', 4740),
#  ('CTTGT', 4739),
#  ('TTAGA', 4738),
#  ('GCAGG', 4728),
#  ('CAGGC', 4721),
#  ('CATGA', 4716),
#  ('TCATG', 4697),
#  ('CTCAC', 4690),
#  ('TGGGG', 4683),
#  ('TCTAT', 4683),
#  ('GAGGG', 4682),
#  ('GTGAG', 4673),
#  ('TCAGG', 4672),
#  ('TTCAC', 4652),
#  ('TACAG', 4646),
#  ('GTGAA', 4645),
#  ('CTGTA', 4644),
#  ('TCTAA', 4638),
#  ('CCTGA', 4627),
#  ('GGTTT', 4609),
#  ('AGCAC', 4599),
#  ('TATCT', 4586),
#  ('TGATG', 4585),
#  ('CCCCA', 4580),
#  ('CATAA', 4577),
#  ('GTCTG', 4576),
#  ('CATCA', 4572),
#  ('ATCCT', 4567),
#  ('CAGAC', 4565),
#  ('GAAGT', 4551),
#  ('AAGCC', 4551),
#  ('CTTAA', 4550),
#  ('AGATA', 4550),
#  ('ATAGA', 4532),
#  ('AAACC', 4524),
#  ('GTGCT', 4521),
#  ('ACTTC', 4518),
#  ('TGAGC', 4516),
#  ('TTGAG', 4514),
#  ('ATCTC', 4511),
#  ('GCATT', 4505),
#  ('TGTTA', 4504),
#  ('GTCTT', 4494),
#  ('AGGAT', 4493),
#  ('GAGAT', 4482),
#  ('CCTTG', 4479),
#  ('CAAGG', 4465),
#  ('TAACA', 4457),
#  ('CCACT', 4449),
#  ('GGCTT', 4446),
#  ('GCTCA', 4445),
#  ('CTCAA', 4429),
#  ('TACTT', 4424),
#  ('TATTC', 4420),
#  ('GCCTT', 4415),
#  ('AGTGG', 4408),
#  ('AAGGG', 4404),
#  ('TTATG', 4400),
#  ('ATTCC', 4394),
#  ('TGCTA', 4393),
#  ('CATGG', 4386),
#  ('GGAAT', 4383),
#  ('AATGC', 4374),
#  ('TGGAT', 4371),
#  ('CCACC', 4371),
#  ('AAGGC', 4369),
#  ('AAGAC', 4360),
#  ('GGTGG', 4359),
#  ('TGGGT', 4355),
#  ('AATGG', 4355),
#  ('GGGGA', 4349),
#  ('CCATG', 4346),
#  ('ATTGT', 4340),
#  ('TTACT', 4335),
#  ('CCATT', 4333),
#  ('TAGCA', 4324),
#  ('ACCCA', 4314),
#  ('AAGTA', 4313),
#  ('TTTAC', 4309),
#  ('ACTTG', 4296),
#  ('TTAAG', 4283),
#  ('CCCTT', 4282),
#  ('CTATT', 4279),
#  ('AGTTC', 4276),
#  ('CCAGT', 4274),
#  ('TCAAG', 4273),
#  ('TCCCC', 4269),
#  ('GAATA', 4263),
#  ('TCATC', 4260),
#  ('ATCAT', 4259),
#  ('ACTGG', 4257),
#  ('CCATC', 4253),
#  ('GAGTT', 4247),
#  ('GAGAC', 4240),
#  ('CAAGT', 4236),
#  ('CTTGA', 4232),
#  ('GCAAG', 4230),
#  ('GATGA', 4230),
#  ('TAGCT', 4228),
#  ('GATGG', 4226),
#  ('ATGAT', 4221),
#  ('ACAAT', 4221),
#  ('AGTAA', 4219),
#  ('ACCAG', 4219),
#  ('GAGTG', 4213),
#  ('GTAAA', 4189),
#  ('ATCCA', 4182),
#  ('ACTGC', 4181),
#  ('TTGTA', 4176),
#  ('CTTGC', 4176),
#  ('CACTC', 4176),
#  ('CTGAT', 4169),
#  ('TAGAG', 4167),
#  ('GAACT', 4163),
#  ('GTGGA', 4152),
#  ('TATGA', 4145),
#  ('TCCAC', 4144),
#  ('GGATG', 4132),
#  ('CTCTA', 4129),
#  ('CATCC', 4122),
#  ('CATGC', 4120),
#  ('GCATG', 4119),
#  ('AACTC', 4112),
#  ('AATTG', 4105),
#  ('AGCTA', 4101),
#  ('AATAG', 4097),
#  ('ATCAG', 4094),
#  ('TTGTC', 4091),
#  ('GTCTC', 4089),
#  ('CTGGT', 4089),
#  ('TCATA', 4088),
#  ('TACAA', 4067),
#  ('TGTAG', 4042),
#  ('GACTG', 4039),
#  ('CAAGC', 4033),
#  ('CAATT', 4027),
#  ('ACATC', 4024),
#  ('GCCTC', 4023),
#  ('GATGT', 4015),
#  ('TATTA', 4002),
#  ('GTTTA', 3998),
#  ('CATTG', 3997),
#  ('TTGGT', 3996),
#  ('GACAA', 3978),
#  ('ACCAA', 3974),
#  ('TAATA', 3969),
#  ('GCAGT', 3965),
#  ('CAATG', 3964),
#  ('TTGGG', 3962),
#  ('GAGGC', 3958),
#  ('GCTTG', 3944),
#  ('GGGTG', 3937),
#  ('CTACA', 3933),
#  ('AAGTC', 3925),
#  ('CTGAC', 3902),
#  ('CACCC', 3895),
#  ('TTGAT', 3887),
#  ('TAATG', 3887),
#  ('CAGTC', 3887),
#  ('TAACT', 3883),
#  ('GGAGC', 3880),
#  ('CCCCC', 3876),
#  ('GCTCC', 3874),
#  ('TAAAC', 3867),
#  ('ACCAT', 3859),
#  ('ATCAA', 3858),
#  ('TAGGA', 3856),
#  ('ATGGT', 3855),
#  ('TCTAG', 3849),
#  ('TCCTA', 3841),
#  ('GCCAA', 3838),
#  ('CCCAA', 3835),
#  ('ATAAG', 3831),
#  ('AGGTG', 3829),
#  ('ATGTC', 3824),
#  ('GACTT', 3821),
#  ('GACAT', 3821),
#  ('TACTG', 3819),
#  ('GTTCA', 3819),
#  ('CACCT', 3813),
#  ('CTTAG', 3809),
#  ('TGAAC', 3802),
#  ('TTGGC', 3799),
#  ('AGTTA', 3793),
#  ('TTGCC', 3792),
#  ('GTCAG', 3784),
#  ('CTTAT', 3772),
#  ('CAACT', 3764),
#  ('AGTTG', 3757),
#  ('CTAGA', 3756),
#  ('GAGCC', 3745),
#  ('TGCAC', 3743),
#  ('CAGTA', 3742),
#  ('GTGCA', 3731),
#  ('GGGGG', 3731),
#  ('GGCTC', 3716),
#  ('CATTA', 3711),
#  ('TGTCC', 3710),
#  ('GGCAA', 3708),
#  ('CTAAG', 3698),
#  ('AGGTT', 3696),
#  ('TAGAT', 3692),
#  ('AGGGG', 3681),
#  ('ATCTA', 3676),
#  ('GGGCT', 3667),
#  ('GCCAT', 3663),
#  ('GTGGT', 3658),
#  ('ACTTA', 3657),
#  ('GGAGT', 3649),
#  ('CCCCT', 3648),
#  ('GGACA', 3643),
#  ('TAGTT', 3638),
#  ('GTTCC', 3638),
#  ('CTATG', 3632),
#  ('AACTA', 3620),
#  ('GTTGT', 3618),
#  ('AACCT', 3616),
#  ('CATAG', 3612),
#  ('TATCA', 3605),
#  ('AATCC', 3605),
#  ('CCCAT', 3603),
#  ('ATGGG', 3572),
#  ('TTAGT', 3563),
#  ('ACCTT', 3555),
#  ('GGAAC', 3553),
#  ('TGATA', 3550),
#  ('ATGAC', 3550),
#  ('GTATT', 3548),
#  ('ATGGC', 3548),
#  ('AGGAC', 3548),
#  ('GTCAT', 3546),
#  ('ACCAC', 3545),
#  ('ACTAA', 3539),
#  ('GTGAT', 3538),
#  ('GTCCT', 3532),
#  ('TGGGC', 3530),
#  ('GAGTC', 3530),
#  ('TTATC', 3526),
#  ('TAAGT', 3523),
#  ('ATCAC', 3519),
#  ('ATTGA', 3512),
#  ('AGCCC', 3511),
#  ('ACCTG', 3506),
#  ('GGCAT', 3498),
#  ('ATGCC', 3496),
#  ('GATGC', 3491),
#  ('AAGGT', 3490),
#  ('GGATT', 3476),
#  ('AGTGC', 3476),
#  ('GCACT', 3469),
#  ('ACTCC', 3469),
#  ('GGTGT', 3468),
#  ('GACAC', 3466),
#  ('TCAAT', 3465),
#  ('CAGGT', 3445),
#  ('AGTAT', 3441),
#  ('AATAC', 3438),
#  ('GCCCA', 3437),
#  ('TATTG', 3426),
#  ('ATACT', 3423),
#  ('GATAA', 3411),
#  ('ACAAC', 3409),
#  ('AGTAG', 3405),
#  ('GTGTA', 3402),
#  ('GACTC', 3394),
#  ('GCATC', 3389),
#  ('CTACT', 3383),
#  ('TCACC', 3377),
#  ('GATTC', 3372),
#  ('ATCCC', 3371),
#  ('GCCAC', 3368),
#  ('AGGGT', 3362),
#  ('TATGC', 3358),
#  ('TGCCC', 3354),
#  ('GAATC', 3353),
#  ('GGTGA', 3349),
#  ('GCTAA', 3348),
#  ('TACAC', 3346),
#  ('GATCT', 3338),
#  ('GATAT', 3326),
#  ('AGATC', 3325),
#  ('TTAGC', 3323),
#  ('GTGGC', 3323),
#  ('GTGTC', 3319),
#  ('GCATA', 3315),
#  ('GGGCA', 3307),
#  ('ACACC', 3304),
#  ('TACCA', 3289),
#  ('ACCTC', 3275),
#  ('CTATA', 3265),
#  ('TGGTA', 3261),
#  ('ACCCT', 3261),
#  ('GTCAC', 3260),
#  ('ATTGC', 3259),
#  ('CCATA', 3257),
#  ('TCTAC', 3230),
#  ('CCTTA', 3230),
#  ('GTGAC', 3213),
#  ('TATAG', 3210),
#  ('GTAGA', 3199),
#  ('ACTAT', 3197),
#  ('GCAAT', 3182),
#  ('GCCCT', 3181),
#  ('GGGAT', 3180),
#  ('ATAAC', 3178),
#  ('TTAAC', 3175),
#  ('TAAGG', 3175),
#  ('GCTAT', 3173),
#  ('GAGGT', 3171),
#  ('ATATC', 3171),
#  ('TGGCC', 3170),
#  ('CCAAC', 3164),
#  ('ATAGT', 3157),
#  ('TAAGC', 3150),
#  ('GTTAT', 3140),
#  ('ATTAG', 3136),
#  ('GGCCA', 3133),
#  ('GCTTA', 3133),
#  ('AGGGC', 3133),
#  ('TATGG', 3126),
#  ('ATAGC', 3122),
#  ('GTTAA', 3108),
#  ('GTTGG', 3084),
#  ('CACTA', 3066),
#  ('CAATA', 3058),
#  ('CTAAT', 3053),
#  ('TTAGG', 3049),
#  ('AGTCC', 3026),
#  ('CTTAC', 2991),
#  ('TGTAC', 2990),
#  ('GGCCT', 2988),
#  ('GGGTT', 2980),
#  ('AACCC', 2973),
#  ('GGACT', 2969),
#  ('ATTGG', 2968),
#  ('TAGTG', 2956),
#  ('GTAAT', 2949),
#  ('GTAAG', 2944),
#  ('GTACA', 2931),
#  ('CCTAA', 2923),
#  ('CTAGG', 2906),
#  ('CCAAT', 2899),
#  ('GTATG', 2896),
#  ('AGGCC', 2889),
#  ('GTGCC', 2879),
#  ('ATTAC', 2873),
#  ('GGCAC', 2864),
#  ('GTTGA', 2847),
#  ('TCAAC', 2845),
#  ('GAGTA', 2841),
#  ('CATAC', 2841),
#  ('TATAC', 2840),
#  ('TACCT', 2836),
#  ('CCTAG', 2835),
#  ('AGACC', 2820),
#  ('GGTCT', 2795),
#  ('TTGAC', 2782),
#  ('CAACC', 2775),
#  ('AGGTA', 2767),
#  ('GTATA', 2752),
#  ('TACTC', 2744),
#  ('GTCCA', 2739),
#  ('GATCA', 2712),
#  ('GGTTG', 2708),
#  ('CAATC', 2705),
#  ('TATCC', 2693),
#  ('GGATA', 2693),
#  ('GTCAA', 2688),
#  ('TGATC', 2687),
#  ('CTAGC', 2683),
#  ('GTTGC', 2663),
#  ('TAATC', 2654),
#  ('GCTAG', 2650),
#  ('GATTA', 2650),
#  ('GACCA', 2650),
#  ('TGGTC', 2636),
#  ('CCTAT', 2632),
#  ('GGTTC', 2627),
#  ('GCAAC', 2616),
#  ('ACTAG', 2609),
#  ('CTAGT', 2589),
#  ('TAGGT', 2563),
#  ('GTAGG', 2563),
#  ('TGGAC', 2562),
#  ('TAGTA', 2560),
#  ('ACCCC', 2553),
#  ('GATTG', 2546),
#  ('GTCTA', 2545),
#  ('GAACC', 2540),
#  ('ATAGG', 2535),
#  ('GGGGT', 2530),
#  ('GTTAG', 2517),
#  ('CTATC', 2517),
#  ('TACTA', 2508),
#  ('GACCT', 2508),
#  ('CCTAC', 2507),
#  ('GGGAC', 2503),
#  ('GGCTA', 2496),
#  ('CTAAC', 2495),
#  ('GGTAA', 2482),
#  ('GTCCC', 2477),
#  ('TTACC', 2468),
#  ('GCACC', 2438),
#  ('TAGCC', 2430),
#  ('ACCTA', 2430),
#  ('GATAG', 2426),
#  ('TAGAC', 2417),
#  ('CTACC', 2404),
#  ('TAGGG', 2397),
#  ('CCCTA', 2394),
#  ('GGGGC', 2385),
#  ('AGTAC', 2384),
#  ('AGGTC', 2374),
#  ('GGTGC', 2370),
#  ('GTACT', 2364),
#  ('GCCCC', 2358),
#  ('GGTAG', 2353),
#  ('GTAGC', 2337),
#  ('TGACC', 2336),
#  ('TAGTC', 2334),
#  ('GACTA', 2323),
#  ('GCTAC', 2307),
#  ('GGATC', 2300),
#  ('GATCC', 2265),
#  ('GGTCA', 2256),
#  ('GTTAC', 2238),
#  ('TAGGC', 2233),
#  ('GCCTA', 2233),
#  ('GTAAC', 2226),
#  ('ATACC', 2214),
#  ('GTAGT', 2183),
#  ('GGTAT', 2181),
#  ('ACTAC', 2181),
#  ('TAACC', 2170),
#  ('GGTTA', 2142),
#  ('TACCC', 2107),
#  ('GGGTA', 2087),
#  ('GTATC', 2066),
#  ('GATAC', 2007),
#  ('GGGCC', 1953),
#  ('GGCCC', 1908),
#  ('GGACC', 1865),
#  ('GGGTC', 1839),
#  ('GGTCC', 1838),
#  ('GACCC', 1777),
#  ('GTACC', 1576),
#  ('GGTAC', 1522),
#  ('CGTGG', 1282),
#  ('AAACG', 1242),
#  ('ACACG', 1232),
#  ('ACGTG', 1230),
#  ('CGTGT', 1219),
#  ('CGCTG', 1213),
#  ('CACGT', 1202),
#  ('CCGTG', 1181),
#  ('CCACG', 1168),
#  ('CGTTT', 1147),
#  ('CAGCG', 1137),
#  ('GCGTG', 1106),
#  ('CACGG', 1103),
#  ('CACGC', 1100),
#  ('CTGCG', 1065),
#  ('CGGAG', 1051),
#  ('CTCCG', 1021),
#  ('CTCGG', 984),
#  ('CGTGA', 969),
#  ('CCCCG', 955),
#  ('GCACG', 950),
#  ('AACGT', 940),
#  ('TCCCG', 939),
#  ('CGTGC', 934),
#  ('TCCGT', 933),
#  ('ACGCT', 929),
#  ('AGGCG', 927),
#  ('CGCAG', 926),
#  ('CCGAG', 925),
#  ('CGGGA', 923),
#  ('TCACG', 921),
#  ('ACGTT', 921),
#  ('CGTCT', 917),
#  ('CCTCG', 912),
#  ('CGGGG', 907),
#  ('AGACG', 901),
#  ('CCCGG', 900),
#  ('TGCGT', 898),
#  ('CGCCT', 897),
#  ('AAGCG', 894),
#  ('AGCGT', 892),
#  ('CGGCT', 890),
#  ('TCGTG', 889),
#  ('ACGGA', 885),
#  ('CGAGA', 884),
#  ('ACGCA', 880),
#  ('CCGCC', 876),
#  ('CACCG', 875),
#  ('TTCCG', 874),
#  ('TTCGT', 870),
#  ('CGCCA', 870),
#  ('CACGA', 869),
#  ('CGAGG', 860),
#  ('CGCCC', 858),
#  ('AACGA', 856),
#  ('TCGCT', 854),
#  ('CTTCG', 854),
#  ('GCGCT', 851),
#  ('AGCGA', 848),
#  ('GAGCG', 846),
#  ('CGCTC', 846),
#  ('CCGGG', 846),
#  ('AGCCG', 845),
#  ('CGGAA', 844),
#  ('CCCGC', 843),
#  ('AGCGC', 835),
#  ('TCTCG', 827),
#  ('ACGAA', 824),
#  ('CGGTG', 819),
#  ('CGCTT', 819),
#  ('TGGCG', 813),
#  ('TCGTT', 804),
#  ('CGAAG', 802),
#  ('GCGGG', 799),
#  ('CGTTC', 794),
#  ('AACGG', 790),
#  ('GAACG', 785),
#  ('AGCGG', 784),
#  ('GCGTT', 779),
#  ('CTCGT', 777),
#  ('GCGAG', 776),
#  ('CGGCA', 776),
#  ('CCCGT', 769),
#  ('ACGAG', 765),
#  ('CGAAA', 763),
#  ('GGGCG', 759),
#  ('TTTCG', 752),
#  ('CTCGC', 751),
#  ('CGCAC', 749),
#  ('GGCGG', 748),
#  ('TGCCG', 739),
#  ('ACTCG', 737),
#  ('TGCGG', 736),
#  ('CCGCT', 732),
#  ('CCGCA', 732),
#  ('ACGCC', 731),
#  ('GCGCA', 730),
#  ('AACGC', 730),
#  ('CAACG', 720),
#  ('CGATG', 718),
#  ('TCGGG', 717),
#  ('CGAGC', 716),
#  ('ACGGG', 713),
#  ('CCGTT', 710),
#  ('ATGCG', 707),
#  ('TGCGC', 703),
#  ('CGTTG', 701),
#  ('GTGCG', 699),
#  ('AACCG', 697),
#  ('CCGGA', 693),
#  ('CCGAA', 691),
#  ('CGCAT', 690),
#  ('TCCGG', 687),
#  ('TTCGG', 685),
#  ('CGAAT', 682),
#  ('GGCGT', 681),
#  ('CGTCA', 681),
#  ('ACCGT', 674),
#  ('CGGTT', 663),
#  ('CATCG', 662),
#  ('CCCGA', 660),
#  ('TCGAA', 656),
#  ('TGACG', 654),
#  ('CGAGT', 654),
#  ('TACGT', 652),
#  ('GGCGC', 651),
#  ('GCCCG', 650),
#  ('GCTCG', 649),
#  ('TCGGA', 648),
#  ('TCCGA', 648),
#  ('TCGAG', 646),
#  ('ACGGT', 644),
#  ('CGGGC', 642),
#  ('GGCGA', 641),
#  ('ACGAT', 638),
#  ('ACCGA', 638),
#  ('TTCGA', 637),
#  ('ATTCG', 636),
#  ('TCGGT', 631),
#  ('ACCCG', 629),
#  ('CCGTC', 626),
#  ('ACGTA', 624),
#  ('ACGTC', 621),
#  ('TCGGC', 620),
#  ('TCGCC', 620),
#  ('GCGGA', 619),
#  ('TGCGA', 615),
#  ('GCGCC', 615),
#  ('CTCGA', 614),
#  ('CCGGC', 606),
#  ('GACGT', 605),
#  ('CGGGT', 603),
#  ('AGTCG', 602),
#  ('GCCGT', 597),
#  ('ACCGC', 592),
#  ('CGACT', 590),
#  ('AATCG', 587),
#  ('TCGCA', 586),
#  ('GCGGC', 585),
#  ('ACGGC', 585),
#  ('TCCGC', 582),
#  ('ATCGT', 577),
#  ('CGATT', 576),
#  ('GCCGC', 573),
#  ('GCCGA', 573),
#  ('TAACG', 571),
#  ('ATCCG', 570),
#  ('CGTTA', 567),
#  ('CGCAA', 561),
#  ('TGTCG', 560),
#  ('GACGC', 557),
#  ('CGTCC', 557),
#  ('TCGTC', 554),
#  ('TTCGC', 551),
#  ('GCCGG', 548),
#  ('CGACA', 547),
#  ('GCGAA', 545),
#  ('CGTAT', 543),
#  ('ACCGG', 542),
#  ('CGGAT', 541),
#  ('ATCGC', 540),
#  ('GGACG', 539),
#  ('ATACG', 533),
#  ('CCGGT', 532),
#  ('GCGAT', 523),
#  ('GACGG', 517),
#  ('GACGA', 517),
#  ('CGGCC', 513),
#  ('TTACG', 509),
#  ('GCGGT', 499),
#  ('GTTCG', 498),
#  ('GGCCG', 497),
#  ('CGTAA', 492),
#  ('CGCTA', 492),
#  ('CTACG', 491),
#  ('CGTAG', 485),
#  ('TTGCG', 482),
#  ('GCGTC', 481),
#  ('TAGCG', 480),
#  ('GTCGG', 479),
#  ('TCGAT', 475),
#  ('ATCGA', 471),
#  ('CGAAC', 468),
#  ('ATCGG', 465),
#  ('ACGAC', 459),
#  ('CCGTA', 454),
#  ('CCGAC', 454),
#  ('TACGA', 452),
#  ('GTCGT', 449),
#  ('CCGAT', 449),
#  ('TACCG', 438),
#  ('GACCG', 437),
#  ('CGCGC', 435),
#  ('CGGTA', 430),
#  ('GCGCG', 429),
#  ('TCGTA', 428),
#  ('TACGG', 418),
#  ('CGATC', 414),
#  ('GATCG', 408),
#  ('CGGAC', 404),
#  ...]

# %%
get_sorted_kmer_dict('/home/mleone2/ml_class_project/FASTA_CV/Mo2015_EXCpos_Ctx_fold2_testPos.fa', 5)[:10]
# Out:
# [('TTTTT', 27699),
#  ('AAAAA', 27469),
#  ('TTTCT', 20380),
#  ('AGAAA', 20219),
#  ('ATTTT', 19020),
#  ('AAAAT', 18823),
#  ('TGTGT', 18141),
#  ('AGAGA', 17913),
#  ('ACACA', 17871),
#  ('TCTCT', 17824)]

# %%
get_sorted_kmer_dict('/home/mleone2/ml_class_project/FASTA_CV/Mo2015_EXCpos_Ctx_fold2_validPos.fa', 5)[:10]
# Out:
# [('AAAAA', 18114),
#  ('TTTTT', 17712),
#  ('TTTCT', 13361),
#  ('AGAAA', 13201),
#  ('TGTGT', 12561),
#  ('ATTTT', 12465),
#  ('AAAAT', 12396),
#  ('ACACA', 11839),
#  ('TCTCT', 11528),
#  ('AGAGA', 11218)]

# %%
# negative
get_sorted_kmer_dict('/home/mleone2/ml_class_project/FASTA_CV/Mo2015_EXCpos_Ctx_fold2_testNeg10x.fa', 5)[:10]
# Out:
# [('AAAAA', 208220),
#  ('TTTTT', 206575),
#  ('ACACA', 171285),
#  ('TGTGT', 168144),
#  ('AGAAA', 159294),
#  ('TTTCT', 157815),
#  ('TCTCT', 149928),
#  ('AGAGA', 148601),
#  ('AAGAA', 142029),
#  ('TTCTT', 140352)]

# %%
# simulated
get_sorted_kmer_dict('/home/mleone2/ml_class_project/results/random_seqs_test.fa', 5)[:10]
# Out:
# [('AATTA', 97029),
#  ('TAATT', 96930),
#  ('AAATT', 96863),
#  ('TATAT', 96584),
#  ('TTAAT', 96547),
#  ('TTTAA', 96544),
#  ('ATTAT', 96513),
#  ('AATTT', 96480),
#  ('ATAAT', 96423),
#  ('TTTTT', 96401)]

# %%
for i in range(5, 8):
    print('k =', i)
    print(get_sorted_kmer_dict('/home/mleone2/ml_class_project/FASTA_CV/Mo2015_EXCpos_Ctx_fold1_testPos.fa', i)[:10])
# Out:
# k = 5
# [('TTTTT', 27699), ('AAAAA', 27469), ('TTTCT', 20380), ('AGAAA', 20219), ('ATTTT', 19020), ('AAAAT', 18823), ('TGTGT', 18141), ('AGAGA', 17913), ('ACACA', 17871), ('TCTCT', 17824)]
# k = 6
# [('TTTTTT', 13444), ('AAAAAA', 13353), ('TGTGTG', 9813), ('CACACA', 9613), ('GTGTGT', 8513), ('ACACAC', 8256), ('AGAGAG', 7288), ('TTTTCT', 7218), ('CTCTCT', 7086), ('AGAAAA', 6955)]
# k = 7
# [('TTTTTTT', 8680), ('AAAAAAA', 8656), ('TGTGTGT', 6781), ('ACACACA', 6534), ('GTGTGTG', 6405), ('CACACAC', 6150), ('AGAGAGA', 4633), ('TCTCTCT', 4422), ('GAGAGAG', 4170), ('CTCTCTC', 3906)]

# %%
for i in range(5, 8):
    print('k =', i)
    print(get_sorted_kmer_dict('/home/mleone2/ml_class_project/FASTA_CV/Mo2015_EXCpos_Ctx_fold1_testNeg10x.fa', i)[:10])
# Out:
# k = 5
# [('AAAAA', 208220), ('TTTTT', 206575), ('ACACA', 171285), ('TGTGT', 168144), ('AGAAA', 159294), ('TTTCT', 157815), ('TCTCT', 149928), ('AGAGA', 148601), ('AAGAA', 142029), ('TTCTT', 140352)]
# k = 6
# [('AAAAAA', 96877), ('TTTTTT', 96328), ('CACACA', 94078), ('TGTGTG', 92022), ('ACACAC', 84975), ('GTGTGT', 83040), ('CTCTCT', 60749), ('AGAGAG', 58875), ('TCTCTC', 58600), ('AAGAAA', 58320)]
# k = 7
# [('ACACACA', 69847), ('TGTGTGT', 67949), ('CACACAC', 64012), ('GTGTGTG', 62518), ('TTTTTTT', 58959), ('AAAAAAA', 58924), ('TCTCTCT', 40479), ('AGAGAGA', 38844), ('CTCTCTC', 36743), ('GAGAGAG', 34663)]

# %%
for i in range(5, 8):
    print('k =', i)
    print(get_sorted_kmer_dict('/home/mleone2/ml_class_project/FASTA_CV/Mo2015_EXCpos_Ctx_fold2_testNeg10x.fa', i)[:10])
# Out:
# k = 5
# [('AAAAA', 208220), ('TTTTT', 206575), ('ACACA', 171285), ('TGTGT', 168144), ('AGAAA', 159294), ('TTTCT', 157815), ('TCTCT', 149928), ('AGAGA', 148601), ('AAGAA', 142029), ('TTCTT', 140352)]
# k = 6
# [('AAAAAA', 96877), ('TTTTTT', 96328), ('CACACA', 94078), ('TGTGTG', 92022), ('ACACAC', 84975), ('GTGTGT', 83040), ('CTCTCT', 60749), ('AGAGAG', 58875), ('TCTCTC', 58600), ('AAGAAA', 58320)]
# k = 7
# [('ACACACA', 69847), ('TGTGTGT', 67949), ('CACACAC', 64012), ('GTGTGTG', 62518), ('TTTTTTT', 58959), ('AAAAAAA', 58924), ('TCTCTCT', 40479), ('AGAGAGA', 38844), ('CTCTCTC', 36743), ('GAGAGAG', 34663)]

# %%
for i in range(5, 8):
    print('k =', i)
    print(get_sorted_kmer_dict('/home/mleone2/ml_class_project/FASTA_CV/Mo2015_EXCpos_Ctx_fold2_validNeg10x.fa', i)[:10])
# Out:
# k = 5
# [('AAAAA', 171753), ('TTTTT', 170369), ('TGTGT', 141085), ('ACACA', 137784), ('TTTCT', 132646), ('AGAAA', 131419), ('TCTCT', 126002), ('AGAGA', 124216), ('AAGAA', 117719), ('TTCTT', 117361)]
# k = 6
# [('AAAAAA', 79389), ('TTTTTT', 78443), ('TGTGTG', 75885), ('CACACA', 74261), ('GTGTGT', 68458), ('ACACAC', 66920), ('CTCTCT', 50259), ('AGAGAG', 49415), ('TCTCTC', 48229), ('AAAGAA', 48178)]
# k = 7
# [('TGTGTGT', 55903), ('ACACACA', 54385), ('GTGTGTG', 51304), ('CACACAC', 50059), ('AAAAAAA', 47929), ('TTTTTTT', 47358), ('TCTCTCT', 33023), ('AGAGAGA', 32481), ('CTCTCTC', 29699), ('GAGAGAG', 29244)]
